# %% [markdown]
# # Functions
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 6.1 Prime Number Checker
# Create a program that checks whether a number is a prime number and displays its factors if it is not a prime number.
#
# ### Console:
# ```powershell
# Prime Number Checker
#
# Please enter an integer between 1 and 5000: 5
# 5 is a prime number.
#
# Try again? (y/n): y
#
# Please enter an integer between 1 and 5000: 6
# 6 is NOT a prime number.
# It has 4 factors: 1 2 3 6
#
# Try again? (y/n): y
#
# Please enter an integer between 1 and 5000: 200
# 200 is NOT a prime number.
# It has 12 factors: 1 2 3 4 5 8 10 20 25 40 50 100 200
#
# Try again? (y/n): n
#
# Bye!
# ```
#
# ### Specifications:
# - A prime number is divisible by two factors (1 and itself). For example, 7 is a prime number because it is only divisible by 1 and 7.
# - If the user enters an integer that's not between 1 and 5000, the program should display an error message.
# - If the number is a prime number, the program should display a message.
# If the number is not a prime number, the program should display a message. Then, it should display the number of factors for the number and a list of those factors.
# - Store the factors for each number in a list.
# - Use functions to organize the code for this program.

# %%
print ("Prime Number Checker")
print()

def get_factors(number):
    factors = []
    for x in range(1, number + 1):
        if number %  x == 0:
            factors.append(x)
    return factors
    
def prime(number):    
    x = number
    while True:
        if x  % 2 == 0:
            return False
            if x  % 3 == 0:
                return False
            if x  % 7 == 0:
                return False
            else:
                return True

def main():
    choice = "y"
    while choice == "y":
        number = int(input("Please enter an integer between 1 and 5000: "))
        if number >=1 and number <=5000:
            if prime(number) is True:
                print(number, "is a prime number.")
            else:
                print(number, "is NOT a prime number.")
                print("It has",len(get_factors(number)) ,"factors: ", get_factors(number))
        else:
            print("Choose a valid number between 1 and 5000.")
            
        break
    choice = input("Try again? (y/n): ")
    if choice == "y":
        main()
    if choice != "y":
        print("Bye!")
    
if __name__ == "__main__":
    main()
# Out:
# Prime Number Checker
#
# Please enter an integer between 1 and 5000: 12
# 12 is NOT a prime number.
# It has 6 factors:  [1, 2, 3, 4, 6, 12]
# Try again? (y/n): y
# Please enter an integer between 1 and 5000: 3998
# 3998 is NOT a prime number.
# It has 4 factors:  [1, 2, 1999, 3998]
# Try again? (y/n): 4787
# Bye!

# %% [markdown]
# ## 6.2 - Contact Manager
# Create a program that a user can use to manage the primary email address and phone number for a contact.
#
# ### Console
# ```powershell
# Contact Manager
#
# COMMAND MENU
# list - Display all contacts
# view - View a contact
# add - Add a contact
# del - Delete a contact
# exit - Exit program
#
# Command: list
# 1. Guido van Rossum
# 2. Eric Idle
#
# Command: view
# Number: 2
# Name: Eric Idle
# Email: eric@ericidle.com
# Phone: +44 20 7946 0958
#
# Command: add
# Name: Mike Murach
# Email: mike@murach.com
# Phone: 559-123-4567
# Mike Murach was added.
#
# Command: del
# Number: 1
# Guido van Rossum was deleted.
#
# Command: list
# 1. Eric Idle
# 2. Mike Murach
#
# Command: exit
# Bye!
# ```
#
# ### Specifications:
# - Use a list of lists to store the data for the contacts. Provide starting data for two or more contacts.
# - For the `view` and `del` commands, display an error message if the user enters and invalid contact number.
# - When you exit the program, all changes that you made to the contact list are lost.

# %%
print("Contact Manager")   
print()


def list_contact(contacts):
    for index, contact in enumerate(contacts, start=1):
        print(str(index) + ".", contact[0] )

def view_contact(contacts):
        number = int(input("Number: "))
        if 1 <= number <= len(contacts):
            contact = contacts[number - 1]
            print("Name: ", contact[0])
            print("Email: ", contact[1])
            print("Phone: ", contact[2])
        else:
            print("Invalid contact number.")
            
def add_contact(contacts):
    name = input("Enter name: ")
    email = input("Enter email: ")
    phone = input("Enter phone number: ")
    contacts.append([name, email, phone])
    print(name, "was added.")
    
def del_contact(contacts):
        number = int(input("Number: "))
        if 1 <= number <= len(contacts):
            deleted_contact = contacts.pop(number - 1)
            print(deleted_contact[0], "was deleted.")
        else:
            print("Invalid contact number.")

    
def main():
    contacts = [["Chas Schaeffer", "chas.schaeffer@gmail.com", "925-286-4883"],
        ["Jane Smith", "jane@example.com", "987-654-3210"]]
    option = 0
    while True:
        print("COMMAND MENU")
        print("list - Display all contacts")
        print("view - View a contact")
        print("add - Add a contact")
        print("delete - Delete a contact")
        print("exit - Exit program")
        print()
        option = input("Command: ")
        
        if option == "list":
            list_contact(contacts)
        elif option == "view":
             view_contact(contacts)
        elif option == "add":
            add_contact(contacts)
        elif option == "delete":
            del_contact(contacts)
        elif option == "exit":
            print("Bye!")
            break
        else: 
            print("Error; invalid entry.")
        print()

if __name__ == "__main__":
    main()
# Out:
# Contact Manager
#
# COMMAND MENU
# list - Display all contacts
# view - View a contact
# add - Add a contact
# delete - Delete a contact
# exit - Exit program
#
# Command: list
# 1. Chas Schaeffer
# 2. Jane Smith
#
# COMMAND MENU
# list - Display all contacts
# view - View a contact
# add - Add a contact
# delete - Delete a contact
# exit - Exit program
#
# Command: view
# Number: 2
# Name:  Jane Smith
# Email:  jane@example.com
# Phone:  987-654-3210
#
# COMMAND MENU
# list - Display all contacts
# view - View a contact
# add - Add a contact
# delete - Delete a contact
# exit - Exit program
#
# Command: delete
# Number: 2
# Jane Smith was deleted.
#
# COMMAND MENU
# list - Display all contacts
# view - View a contact
# add - Add a contact
# delete - Delete a contact
# exit - Exit program
#
# Command: add
# Enter name: johnny appleseed
# Enter email: jseed@gmail.com
# Enter phone number: 123-456-7890
# johnny appleseed was added.
#
# COMMAND MENU
# list - Display all contacts
# view - View a contact
# add - Add a contact
# delete - Delete a contact
# exit - Exit program
#
# Command: exit
# Bye!

# %%
# Out:
# Contact Manager
#
# COMMAND MENU
# list - Display all contacts
# view - View a contact
# add - Add a contact
# delete - Delete a contact
# exit - Exit program
#
# Command: add
# Enter name: mhfycjgf
# Enter email: hgfcghfc
# Enter phone number: 87876
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 65
#      62         print()
#      64 if __name__ == "__main__":
# ---> 65     main()
#
# Cell In[50], line 54, in main()
#      52      view_contact(contacts)
#      53 elif option == "add":
# ---> 54     add_contact(contacts)
#      55 elif option == "delete":
#      56     del_contact(contacts)
#
# Cell In[50], line 23, in add_contact(contacts)
#      21 email = input("Enter email: ")
#      22 phone = input("Enter phone number: ")
# ---> 23 contacts.add([name, email, phone])
#      24 print(name, "was added.")
#
# AttributeError: 'tuple' object has no attribute 'add'
